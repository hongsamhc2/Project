# %% [markdown]
# <a href="https://colab.research.google.com/github/hongsamhc2/Project/blob/main/%EC%84%9C%EC%9A%B8%EC%8B%9C%20CCTV-%EC%A0%84%EC%B2%B4%EC%84%B8%EB%8C%80/Seoul_CCTV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# !apt-get install fonts-nanum* -qq

# %%
CCTV_seoul = pd.read_excel('/content/drive/MyDrive/datasets/CCTV/seoul cctv.xlsx')

# %%
CCTV_seoul.head(10)
# Out:
#      기관명    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 0  강 남 구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 1  강 동 구  1879     303.0  387.0  134.0     59    144    194    273    385
# 2  강 북 구  1265     243.0   88.0  141.0     74    145    254      1    319
# 3  강 서 구  1617     219.0  155.0  118.0    230    187    190    264    254
# 4  관 악 구  3985     430.0   56.0  419.0    487    609    619    694    671
# 5  광 진 구  1581     470.0   42.0   83.0     87     64     21    468    346
# 6  구 로 구  3227     852.0  219.0  349.0    187    268    326    540    486
# 7  금 천 구  1634      27.0   17.0  242.0    101    382    136    199    530
# 8  노 원 구  1906     481.0  117.0  203.0     80    461    298    110    156
# 9  도 봉 구   858     197.0   66.0    8.0    185     59    155    117     71

# %%
CCTV_seoul.columns
# Out:
# Index(['기관명', '소계', '2011년 이전', '2012년', '2013년', '2014년', '2015년', '2016년',
#        '2017년', '2018년'],
#       dtype='object')

# %%
CCTV_seoul.rename(columns={CCTV_seoul.columns[0]:'구별'},inplace=True)
CCTV_seoul.head(10)
# Out:
#       구별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 0  강 남 구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 1  강 동 구  1879     303.0  387.0  134.0     59    144    194    273    385
# 2  강 북 구  1265     243.0   88.0  141.0     74    145    254      1    319
# 3  강 서 구  1617     219.0  155.0  118.0    230    187    190    264    254
# 4  관 악 구  3985     430.0   56.0  419.0    487    609    619    694    671
# 5  광 진 구  1581     470.0   42.0   83.0     87     64     21    468    346
# 6  구 로 구  3227     852.0  219.0  349.0    187    268    326    540    486
# 7  금 천 구  1634      27.0   17.0  242.0    101    382    136    199    530
# 8  노 원 구  1906     481.0  117.0  203.0     80    461    298    110    156
# 9  도 봉 구   858     197.0   66.0    8.0    185     59    155    117     71

# %%
CCTV_seoul.sort_values(by='소계',ascending=False)
CCTV_seoul.head(10)
# Out:
#       구별    소계  2011년 이전  2012년  2013년  2014년  2015년  2016년  2017년  2018년
# 0  강 남 구  5221    1944.0  195.0  316.0    430    546    765    577    448
# 1  강 동 구  1879     303.0  387.0  134.0     59    144    194    273    385
# 2  강 북 구  1265     243.0   88.0  141.0     74    145    254      1    319
# 3  강 서 구  1617     219.0  155.0  118.0    230    187    190    264    254
# 4  관 악 구  3985     430.0   56.0  419.0    487    609    619    694    671
# 5  광 진 구  1581     470.0   42.0   83.0     87     64     21    468    346
# 6  구 로 구  3227     852.0  219.0  349.0    187    268    326    540    486
# 7  금 천 구  1634      27.0   17.0  242.0    101    382    136    199    530
# 8  노 원 구  1906     481.0  117.0  203.0     80    461    298    110    156
# 9  도 봉 구   858     197.0   66.0    8.0    185     59    155    117     71

# %%
CCTV_seoul['CCTV증가율'] = (CCTV_seoul['2018년']+CCTV_seoul['2017년']+CCTV_seoul['2016년']+CCTV_seoul['2015년']+CCTV_seoul['2014년']+CCTV_seoul['2013년']+CCTV_seoul['2012년'])/CCTV_seoul['2011년 이전'] * 100

# %%
CCTV_seoul.head(10)
# Out:
#       구별    소계  2011년 이전  2012년  2013년  ...  2015년  2016년  2017년  2018년      CCTV증가율
# 0  강 남 구  5221    1944.0  195.0  316.0  ...    546    765    577    448   168.569959
# 1  강 동 구  1879     303.0  387.0  134.0  ...    144    194    273    385   520.132013
# 2  강 북 구  1265     243.0   88.0  141.0  ...    145    254      1    319   420.576132
# 3  강 서 구  1617     219.0  155.0  118.0  ...    187    190    264    254   638.356164
# 4  관 악 구  3985     430.0   56.0  419.0  ...    609    619    694    671   826.744186
# 5  광 진 구  1581     470.0   42.0   83.0  ...     64     21    468    346   236.382979
# 6  구 로 구  3227     852.0  219.0  349.0  ...    268    326    540    486   278.755869
# 7  금 천 구  1634      27.0   17.0  242.0  ...    382    136    199    530  5951.851852
# 8  노 원 구  1906     481.0  117.0  203.0  ...    461    298    110    156   296.257796
# 9  도 봉 구   858     197.0   66.0    8.0  ...     59    155    117     71   335.532995
#
# [10 rows x 11 columns]

# %%
def SplitSpace(x):
  x = x.split(' ')
  return ''.join(x)

# %%
CCTV_seoul['구별'] = CCTV_seoul['구별'].apply(lambda x : SplitSpace(x))

# %%
CCTV_seoul
# Out:
#       구별    소계  2011년 이전  2012년  ...  2016년  2017년  2018년       CCTV증가율
# 0    강남구  5221    1944.0  195.0  ...    765    577    448    168.569959
# 1    강동구  1879     303.0  387.0  ...    194    273    385    520.132013
# 2    강북구  1265     243.0   88.0  ...    254      1    319    420.576132
# 3    강서구  1617     219.0  155.0  ...    190    264    254    638.356164
# 4    관악구  3985     430.0   56.0  ...    619    694    671    826.744186
# 5    광진구  1581     470.0   42.0  ...     21    468    346    236.382979
# 6    구로구  3227     852.0  219.0  ...    326    540    486    278.755869
# 7    금천구  1634      27.0   17.0  ...    136    199    530   5951.851852
# 8    노원구  1906     481.0  117.0  ...    298    110    156    296.257796
# 9    도봉구   858     197.0   66.0  ...    155    117     71    335.532995
# 10  동대문구  2003       NaN    NaN  ...    233    136    197           NaN
# 11   동작구  1780     238.0   93.0  ...    254    278    255    647.899160
# ...

# %%
df_pop = pd.read_csv('/content/drive/MyDrive/datasets/CCTV/seoul population.txt',sep='\t')

# %%
df_pop
# Out:
#           기간   자치구       전체세대       1인세대  ...   7인세대   8인세대 9인세대 10인세대 이상
# 0   2020.3/4    합계  4,405,833  1,838,743  ...  7,698  2,104  656      524
# 1   2020.3/4   종로구     74,861     38,033  ...    169     42   10       17
# 2   2020.3/4    중구     63,594     31,995  ...     99     26   12       18
# 3   2020.3/4   용산구    112,451     54,198  ...    192     57   25       20
# 4   2020.3/4   성동구    136,096     57,089  ...    229     65   15       16
# 5   2020.3/4   광진구    166,857     77,584  ...    264     62   23       18
# 6   2020.3/4  동대문구    167,232     79,410  ...    263     70   19       12
# 7   2020.3/4   중랑구    185,109     78,632  ...    281     65   19       14
# 8   2020.3/4   성북구    195,379     78,172  ...    365     89   26       37
# 9   2020.3/4   강북구    145,790     62,219  ...    193     67   16       20
# 10  2020.3/4   도봉구    139,029     46,767  ...    259     72   28        8
# 11  2020.3/4   노원구    218,002     71,857  ...    351    108   33       19
# ...

# %%
df_pop.rename(columns={df_pop.columns[1]:'구별'},inplace=True)

# %%
df_pop
# Out:
#           기간    구별       전체세대       1인세대  ...   7인세대   8인세대 9인세대 10인세대 이상
# 0   2020.3/4    합계  4,405,833  1,838,743  ...  7,698  2,104  656      524
# 1   2020.3/4   종로구     74,861     38,033  ...    169     42   10       17
# 2   2020.3/4    중구     63,594     31,995  ...     99     26   12       18
# 3   2020.3/4   용산구    112,451     54,198  ...    192     57   25       20
# 4   2020.3/4   성동구    136,096     57,089  ...    229     65   15       16
# 5   2020.3/4   광진구    166,857     77,584  ...    264     62   23       18
# 6   2020.3/4  동대문구    167,232     79,410  ...    263     70   19       12
# 7   2020.3/4   중랑구    185,109     78,632  ...    281     65   19       14
# 8   2020.3/4   성북구    195,379     78,172  ...    365     89   26       37
# 9   2020.3/4   강북구    145,790     62,219  ...    193     67   16       20
# 10  2020.3/4   도봉구    139,029     46,767  ...    259     72   28        8
# 11  2020.3/4   노원구    218,002     71,857  ...    351    108   33       19
# ...

# %%
df_result = pd.merge(CCTV_seoul,df_pop,on='구별')

# %%
df_result
# Out:
#       구별    소계  2011년 이전  2012년  2013년  ...   6인세대  7인세대  8인세대  9인세대  10인세대 이상
# 0    강남구  5221    1944.0  195.0  316.0  ...  2,065   541   155    65        36
# 1    강동구  1879     303.0  387.0  134.0  ...  1,487   373   100    23        21
# 2    강북구  1265     243.0   88.0  141.0  ...    938   193    67    16        20
# 3    강서구  1617     219.0  155.0  118.0  ...  1,799   447   106    34        15
# 4    관악구  3985     430.0   56.0  419.0  ...  1,317   312    74    23        26
# 5    광진구  1581     470.0   42.0   83.0  ...  1,058   264    62    23        18
# 6    구로구  3227     852.0  219.0  349.0  ...  1,354   324    83    28        13
# 7    금천구  1634      27.0   17.0  242.0  ...    682   163    45    16        15
# 8    노원구  1906     481.0  117.0  203.0  ...  1,543   351   108    33        19
# 9    도봉구   858     197.0   66.0    8.0  ...  1,088   259    72    28         8
# 10  동대문구  2003       NaN    NaN    NaN  ...  1,108   263    70    19        12
# ...

# %%
df_result.set_index(df_result['구별'],inplace=True)
df_result
# Out:
#         구별    소계  2011년 이전  2012년  2013년  ...   6인세대  7인세대  8인세대  9인세대  10인세대 이상
# 구별                                        ...
# 강남구    강남구  5221    1944.0  195.0  316.0  ...  2,065   541   155    65        36
# 강동구    강동구  1879     303.0  387.0  134.0  ...  1,487   373   100    23        21
# 강북구    강북구  1265     243.0   88.0  141.0  ...    938   193    67    16        20
# 강서구    강서구  1617     219.0  155.0  118.0  ...  1,799   447   106    34        15
# 관악구    관악구  3985     430.0   56.0  419.0  ...  1,317   312    74    23        26
# 광진구    광진구  1581     470.0   42.0   83.0  ...  1,058   264    62    23        18
# 구로구    구로구  3227     852.0  219.0  349.0  ...  1,354   324    83    28        13
# 금천구    금천구  1634      27.0   17.0  242.0  ...    682   163    45    16        15
# 노원구    노원구  1906     481.0  117.0  203.0  ...  1,543   351   108    33        19
# 도봉구    도봉구   858     197.0   66.0    8.0  ...  1,088   259    72    28         8
# ...

# %%
import matplotlib.font_manager as fm
path = '/usr/share/fonts/truetype/nanum/NanumGothicEco.ttf'  # 설치된 나눔글꼴중 원하는 녀석의 전체 경로를 가져오자
font_name = fm.FontProperties(fname=path, size=10).get_name()
print(font_name)
plt.rc('font', family=font_name)
fm._rebuild()
plt.figure()
df_result['소계'].plot(kind='barh',grid=True,figsize=(10,10))
# Out:
# NanumGothic Eco

# %%
df_result.sort_values(by='전체세대',inplace=True)

# %%
plt.figure(figsize=(20,10))
plt.scatter(df_result['전체세대'],df_result['소계'],s=50)
plt.xlabel('전체세대수')
plt.ylabel('CCTV')
plt.grid()
plt.show()

# %%
df_result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 25 entries, 용산구 to 종로구
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   구별        25 non-null     object
#  1   소계        25 non-null     int64
#  2   2011년 이전  23 non-null     float64
#  3   2012년     23 non-null     float64
#  4   2013년     23 non-null     float64
#  5   2014년     25 non-null     int64
#  6   2015년     25 non-null     int64
#  7   2016년     25 non-null     int64
#  8   2017년     25 non-null     int64
#  9   2018년     25 non-null     int64
#  10  CCTV증가율   23 non-null     float64
#  11  기간        25 non-null     object
#  12  전체세대      25 non-null     object
#  13  1인세대      25 non-null     object
#  14  2인세대      25 non-null     object
#  15  3인세대      25 non-null     object
#  16  4인세대      25 non-null     object
#  17  5인세대      25 non-null     object
#  18  6인세대      25 non-null     object
#  19  7인세대      25 non-null     object
# ...

# %%
df_result['전체세대'] = df_result['전체세대'].apply(lambda x : x.replace(',',''))

# %%
df_result['전체세대'] = df_result['전체세대'].astype(float)

# %%
df_result_max = df_result['전체세대'].max()
df_result_min = df_result['전체세대'].min()

# %%
cp1 = np.polyfit(df_result['전체세대'],df_result['소계'],1)
f1 = np.poly1d(cp1)
fx = np.linspace(df_result_min,df_result_max,100)

# %%
plt.figure(figsize=(20,10))
plt.scatter(df_result['전체세대'],df_result['소계'],s=50)
plt.plot(fx,f1(fx),ls='dashed',lw=3,color='g')
plt.xlabel('전체세대수')
plt.ylabel('CCTV')
plt.grid()
plt.show()

# %%
df_result['CCTV-세대 차'] = abs(df_result['소계'] - f1(df_result['전체세대']))

# %%
df_result['CCTV-세대 차']
# Out:
# 구별
# 용산구      294.956361
# 금천구      144.212715
# 성동구      743.513603
# 도봉구     1098.256522
# 서대문구     126.042921
# 강북구      739.134741
# 광진구      572.321316
# 동대문구     152.976890
# 서초구      634.756471
# 마포구      300.736153
# 구로구      982.079104
# 양천구      526.417953
# 영등포구     233.826994
# 동작구      496.086706
# 중랑구     1214.573387
# 강동구      470.798344
# 성북구      647.699308
# 은평구      481.639503
# 노원구      609.506127
# 강남구     2592.054857
# 강서구     1240.997204
# 관악구     1064.104653
# 송파구     1378.581300
# 중구       121.938633
# 종로구       30.848957
# Name: CCTV-세대 차, dtype: float64

# %%
df_diff = df_result.sort_values(by='CCTV-세대 차',inplace=False)

# %%
plt.figure(figsize=(14,10))
plt.scatter(df_result['전체세대'],df_result['소계'],
            s = 50,c = df_result['CCTV-세대 차'])
plt.plot(fx,f1(fx),ls='dashed',lw=3,color='g')

for _ in range(len(df_result)):
  plt.text(df_diff['전체세대'][_]*1.02,df_diff['소계'][_]*0.98,
           df_diff.index[_],fontsize=10)
plt.xlabel('전체세대')
plt.ylabel('세대당 비율')
plt.colorbar()
plt.grid()
plt.show()
